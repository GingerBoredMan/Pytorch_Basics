# %%
import torch
import numpy as np

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

num_workers = 8
batch_size = 32
val_size = 0.2

transform = transforms.Compose([
    transforms.RandomHorizontalFlip(), # randomly flip and rotate
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms. Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])


train_data = datasets.CIFAR10('data', train  = True, download = True, transform = transform)
test_data = datasets.CIFAR10('data', train = False, download = True, transform = transform)

num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, sampler=train_sampler, num_workers = num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, sampler=valid_sampler, num_workers = num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def imshow(img):
    img = img / 2 + 0.5
    plt.imshow(np.transpose(img, (1, 2, 0)))

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

fig = plt.figure(figsize=(25, 4))

for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %%
rgb_img = np.squeeze(images[3])
channels = ['red channel', 'green channel', 'blue channel']

fig = plt.figure(figsize = (36, 36)) 
for idx in np.arange(rgb_img.shape[0]):
    ax = fig.add_subplot(1, 3, idx + 1)
    img = rgb_img[idx]
    ax.imshow(img, cmap='gray')
    ax.set_title(channels[idx])
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            val = round(img[x][y],2) if img[x][y] !=0 else 0
            ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center', size=8,
                    color='white' if img[x][y]<thresh else 'black')

# %%
import torch.nn as nn
import torch.nn.functional as F

class Network(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.conv1 = nn.Conv2d(3, 16, 3, padding = 1)
        self.conv2 = nn.Conv2d(16, 32, 3, padding = 1)
        self.conv3 = nn.Conv2d(32, 64, 3, padding = 1)
        
        self.pool = nn.MaxPool2d(2,2)
        
        self.fc1 = nn.Linear(64*4*4, 512)
        self.fc2 = nn.Linear(512,10)
        self.dropout = nn.Dropout(0.24)
        
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        
        x = x.view(-1,64*4*4)
        x = self.dropout(x)
        
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        
        x = self.fc2(x)
        return x

model = Network()
print(model)

model.cuda()
# Out:
# Network(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.24)
# )
# Network(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.24)
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(model.parameters(), lr = 0.01)

# %%
# %time
epochs = 25

valid_loss_min = np.Inf

for epoch in range(epochs):
    
    train_loss = 0.0
    val_loss = 0.0
    model.train()
    for data,label in train_loader:
        data, label = data.cuda(), label.cuda()
        
        optimizer.zero_grad()
        
        output = model(data)
        loss = criterion(output,label)
        
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()*data.size(0)
        
    model.eval()
    for data,label in valid_loader:
        data, label = data.cuda(), label.cuda()
        
        output = model(data)

        loss = criterion(output, label)
        val_loss += loss.item()*data.size(0)
    
    train_loss = train_loss/len(train_loader.dataset)
    val_loss = val_loss/len(valid_loader.dataset)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(epoch, train_loss, val_loss))
    
    if val_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        val_loss))
        torch.save(model.state_dict(), 'model_cifar.pt')
        valid_loss_min = val_loss
        
# %time
# Out:
# CPU times: user 8 µs, sys: 0 ns, total: 8 µs
# Wall time: 16.5 µs
# Epoch: 0 	Training Loss: 1.720441 	Validation Loss: 0.381983
# Validation loss decreased (inf --> 0.381983).  Saving model ...
# Epoch: 1 	Training Loss: 1.438318 	Validation Loss: 0.336124
# Validation loss decreased (0.381983 --> 0.336124).  Saving model ...
# Epoch: 2 	Training Loss: 1.315877 	Validation Loss: 0.318170
# Validation loss decreased (0.336124 --> 0.318170).  Saving model ...
# Epoch: 3 	Training Loss: 1.231738 	Validation Loss: 0.292155
# Validation loss decreased (0.318170 --> 0.292155).  Saving model ...
# Epoch: 4 	Training Loss: 1.162917 	Validation Loss: 0.274369
# Validation loss decreased (0.292155 --> 0.274369).  Saving model ...
# Epoch: 5 	Training Loss: 1.110292 	Validation Loss: 0.263125
# Validation loss decreased (0.274369 --> 0.263125).  Saving model ...
# Epoch: 6 	Training Loss: 1.064667 	Validation Loss: 0.252864
# Validation loss decreased (0.263125 --> 0.252864).  Saving model ...
# Epoch: 7 	Training Loss: 1.029794 	Validation Loss: 0.241540
# Validation loss decreased (0.252864 --> 0.241540).  Saving model ...
# Epoch: 8 	Training Loss: 0.993760 	Validation Loss: 0.232764
# Validation loss decreased (0.241540 --> 0.232764).  Saving model ...
# Epoch: 9 	Training Loss: 0.960176 	Validation Loss: 0.223195
# Validation loss decreased (0.232764 --> 0.223195).  Saving model ...
# Epoch: 10 	Training Loss: 0.932093 	Validation Loss: 0.219932
# Validation loss decreased (0.223195 --> 0.219932).  Saving model ...
# Epoch: 11 	Training Loss: 0.899619 	Validation Loss: 0.212620
# Validation loss decreased (0.219932 --> 0.212620).  Saving model ...
# Epoch: 12 	Training Loss: 0.875661 	Validation Loss: 0.211142
# Validation loss decreased (0.212620 --> 0.211142).  Saving model ...
# Epoch: 13 	Training Loss: 0.851551 	Validation Loss: 0.198926
# Validation loss decreased (0.211142 --> 0.198926).  Saving model ...
# Epoch: 14 	Training Loss: 0.833957 	Validation Loss: 0.193919
# Validation loss decreased (0.198926 --> 0.193919).  Saving model ...
# Epoch: 15 	Training Loss: 0.816367 	Validation Loss: 0.196580
# Epoch: 16 	Training Loss: 0.792655 	Validation Loss: 0.186878
# Validation loss decreased (0.193919 --> 0.186878).  Saving model ...
# Epoch: 17 	Training Loss: 0.774658 	Validation Loss: 0.186444
# Validation loss decreased (0.186878 --> 0.186444).  Saving model ...
# Epoch: 18 	Training Loss: 0.761720 	Validation Loss: 0.179856
# Validation loss decreased (0.186444 --> 0.179856).  Saving model ...
# Epoch: 19 	Training Loss: 0.743744 	Validation Loss: 0.177345
# Validation loss decreased (0.179856 --> 0.177345).  Saving model ...
# Epoch: 20 	Training Loss: 0.731399 	Validation Loss: 0.177193
# Validation loss decreased (0.177345 --> 0.177193).  Saving model ...
# Epoch: 21 	Training Loss: 0.714659 	Validation Loss: 0.172600
# Validation loss decreased (0.177193 --> 0.172600).  Saving model ...
# Epoch: 22 	Training Loss: 0.703928 	Validation Loss: 0.169128
# Validation loss decreased (0.172600 --> 0.169128).  Saving model ...
# Epoch: 23 	Training Loss: 0.690097 	Validation Loss: 0.164761
# Validation loss decreased (0.169128 --> 0.164761).  Saving model ...
# Epoch: 24 	Training Loss: 0.676943 	Validation Loss: 0.169054
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.72 µs

# %%
model.load_state_dict(torch.load('model_cifar.pt'))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
##########################
## WITH AUGMENTATION ##
##########################

test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval()

for batch_idx, (data, target) in enumerate(test_loader):
    data, target = data.cuda(), target.cuda()
    
    output = model(data)
    loss = criterion(output, target)

    test_loss += loss.item()*data.size(0)
    _, pred = torch.max(output, 1)    

    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.cpu().numpy())

    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.792635
#
# Test Accuracy of airplane: 75% (360/474)
# Test Accuracy of automobile: 87% (423/481)
# Test Accuracy of  bird: 60% (319/528)
# Test Accuracy of   cat: 56% (283/500)
# Test Accuracy of  deer: 57% (287/497)
# Test Accuracy of   dog: 65% (337/513)
# Test Accuracy of  frog: 88% (460/517)
# Test Accuracy of horse: 77% (374/483)
# Test Accuracy of  ship: 82% (412/501)
# Test Accuracy of truck: 74% (385/514)
#
# Test Accuracy (Overall): 72% (3640/5008)

# %%
train)
