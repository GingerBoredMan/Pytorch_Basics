# %%
import torch
import numpy as np

# %%
from torchvision import datasets
import torchvision.transforms as transforms

num_workers = 8

batch_size = 32

transform = transforms.ToTensor()

train_data = datasets.MNIST(root='data', train = True, download = True, transform = transform)
test_data = datasets.MNIST(root='data', train = False, download = True, transform = transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size = batch_size, num_workers=num_workers)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

fig = plt.figure(figsize=(25, 4))
for idx in np.arange(16):
    ax = fig.add_subplot(2, 16/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title(str(labels[idx].item()))

# %%
img = np.squeeze(images[1])

fig = plt.figure(figsize = (12,12)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')
width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        val = round(img[x][y],2) if img[x][y] !=0 else 0
        ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center',
                    color='white' if img[x][y]<thresh else 'black')

# %%
import torch.nn as nn
import torch.nn.functional as F

class model(nn.Module):
    def __init__(self):
        super().__init__()
        hidden_1 = 512
        hidden_2 = 512
        self.fc1 = nn.Linear(784, hidden_1)
        self.fc2 = nn.Linear(hidden_1, hidden_2)
        self.fc3 = nn.Linear(hidden_2, 10)
        
        self.dropout = nn.Dropout(0.2)
        
    def forward(self,x):
        x = x.view(-1,784)
        
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        
        x = self.fc3(x)
        
        return x

model = model()
print(model)
# Out:
# model(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2)
# )

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr = 0.01)

# %%
# training with hidden_layer2 = 512
epochs = 50

validation_loss_min = np.Inf

for epoch in range(epochs):
    train_loss = 0.0
    val_loss = 0.0
    
    model.train()
    for data, label in train_loader:
        
        optimizer.zero_grad()
        
        output = model(data)
        loss = criterion(output, label)
        
        loss.backward()
        
        optimizer.step()
        
        train_loss += loss.item()*data.size(0)
        
    model.eval()
    for data, label in test_loader:
        
        output = model(data)
        loss = criterion(output, label)
        val_loss += loss.item()*data.size(0)
        
    train_loss = train_loss/len(train_loader.dataset)
    val_loss = val_loss/len(test_loader.dataset)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        val_loss
        ))
    
    if val_loss <= validation_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        validation_loss_min,
        val_loss))
        torch.save(model.state_dict(), 'model.pt')
        validation_loss_min = val_loss
# Out:
# Epoch: 1 	Training Loss: 0.518119 	Validation Loss: 0.278913
# Validation loss decreased (inf --> 0.278913).  Saving model ...
# Epoch: 2 	Training Loss: 0.432498 	Validation Loss: 0.320039
# Epoch: 3 	Training Loss: 0.381674 	Validation Loss: 0.287584
# Epoch: 4 	Training Loss: 0.375985 	Validation Loss: 0.310250
# Epoch: 5 	Training Loss: 0.362030 	Validation Loss: 0.274654
# Validation loss decreased (0.278913 --> 0.274654).  Saving model ...
# Epoch: 6 	Training Loss: 0.356524 	Validation Loss: 0.228679
# Validation loss decreased (0.274654 --> 0.228679).  Saving model ...
# Epoch: 7 	Training Loss: 0.337957 	Validation Loss: 0.211151
# Validation loss decreased (0.228679 --> 0.211151).  Saving model ...
# Epoch: 8 	Training Loss: 0.328206 	Validation Loss: 0.310126
# Epoch: 9 	Training Loss: 0.342197 	Validation Loss: 0.259437
# Epoch: 10 	Training Loss: 0.321679 	Validation Loss: 0.306226
# Epoch: 11 	Training Loss: 0.318255 	Validation Loss: 0.337734
# Epoch: 12 	Training Loss: 0.322599 	Validation Loss: 0.296228
# Epoch: 13 	Training Loss: 0.342520 	Validation Loss: 0.293205
# Epoch: 14 	Training Loss: 0.305429 	Validation Loss: 0.312113
# Epoch: 15 	Training Loss: 0.314246 	Validation Loss: 0.345704
# Epoch: 16 	Training Loss: 0.298920 	Validation Loss: 0.339572
# Epoch: 17 	Training Loss: 0.300696 	Validation Loss: 0.306427
# Epoch: 18 	Training Loss: 0.311282 	Validation Loss: 0.320633
# Epoch: 19 	Training Loss: 0.303847 	Validation Loss: 0.355222
# Epoch: 20 	Training Loss: 0.299605 	Validation Loss: 0.437291
# Epoch: 21 	Training Loss: 0.294666 	Validation Loss: 0.401027
# Epoch: 22 	Training Loss: 0.333192 	Validation Loss: 0.494057
# Epoch: 23 	Training Loss: 0.306457 	Validation Loss: 0.443425
# Epoch: 24 	Training Loss: 0.314908 	Validation Loss: 0.379974
# Epoch: 25 	Training Loss: 0.285506 	Validation Loss: 0.365418
# Epoch: 26 	Training Loss: 0.303108 	Validation Loss: 0.435221
# Epoch: 27 	Training Loss: 0.310522 	Validation Loss: 0.417300
# Epoch: 28 	Training Loss: 0.293853 	Validation Loss: 0.417261
# Epoch: 29 	Training Loss: 0.294369 	Validation Loss: 0.446096
# Epoch: 30 	Training Loss: 0.309112 	Validation Loss: 0.412899
# Epoch: 31 	Training Loss: 0.283949 	Validation Loss: 0.386179
# Epoch: 32 	Training Loss: 0.295278 	Validation Loss: 0.388186
# Epoch: 33 	Training Loss: 0.302536 	Validation Loss: 0.449542
# Epoch: 34 	Training Loss: 0.283091 	Validation Loss: 0.608778
# Epoch: 35 	Training Loss: 0.303342 	Validation Loss: 0.398381
# Epoch: 36 	Training Loss: 0.280537 	Validation Loss: 0.497975
# Epoch: 37 	Training Loss: 0.295251 	Validation Loss: 0.590525
# Epoch: 38 	Training Loss: 0.316139 	Validation Loss: 0.711648
# Epoch: 39 	Training Loss: 0.313788 	Validation Loss: 0.505441
# Epoch: 40 	Training Loss: 0.271118 	Validation Loss: 0.534460
# Epoch: 41 	Training Loss: 0.291460 	Validation Loss: 0.614396
# Epoch: 42 	Training Loss: 0.307663 	Validation Loss: 0.447237
# Epoch: 43 	Training Loss: 0.315221 	Validation Loss: 0.444233
# Epoch: 44 	Training Loss: 0.302064 	Validation Loss: 0.623900
# Epoch: 45 	Training Loss: 0.288551 	Validation Loss: 0.627091
# Epoch: 46 	Training Loss: 0.317794 	Validation Loss: 0.547955
# Epoch: 47 	Training Loss: 0.303250 	Validation Loss: 0.607292
# Epoch: 48 	Training Loss: 0.289292 	Validation Loss: 0.659656
# Epoch: 49 	Training Loss: 0.297863 	Validation Loss: 0.614129
# Epoch: 50 	Training Loss: 0.299736 	Validation Loss: 0.689751

# %%
model.load_state_dict(torch.load('model.pt'))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval() 
for data, target in test_loader:
    output = model(data)
    loss = criterion(output, target)
    test_loss += loss.item()*data.size(0)
  
    _, pred = torch.max(output, 1)
      correct = np.squeeze(pred.eq(target.data.view_as(pred)))
   
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            str(i), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.211151
#
# Test Accuracy of     0: 98% (966/980)
# Test Accuracy of     1: 97% (1110/1135)
# Test Accuracy of     2: 94% (974/1032)
# Test Accuracy of     3: 90% (917/1010)
# Test Accuracy of     4: 95% (934/982)
# Test Accuracy of     5: 97% (869/892)
# Test Accuracy of     6: 93% (899/958)
# Test Accuracy of     7: 97% (1005/1028)
# Test Accuracy of     8: 92% (905/974)
# Test Accuracy of     9: 93% (947/1009)
#
# Test Accuracy (Overall): 95% (9526/10000)

# %%
dataiter = iter(test_loader)
images, labels = dataiter.next()


output = model(images)

_, preds = torch.max(output, 1)

images = images.numpy()


fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                 color=("green" if preds[idx]==labels[idx] else "red"))
